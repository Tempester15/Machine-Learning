# %% [markdown]
# <a href="https://colab.research.google.com/github/Tempester15/Machine-Learning/blob/main/Data%20Visualization/Matplotlib_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xkcd
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for xkcd: filename=xkcd-2.4.2-py3-none-any.whl size=9178 sha256=901136d459a295db09b2d151239241ea2cef21ab8a971b66cd3a60ddab055606
#   Stored in directory: /root/.cache/pip/wheels/56/4f/57/af25cb6a39ac6ab34160ff34306bb61558baa553b83f842082
# Successfully built xkcd
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
def generate_data():
  x = np.linspace(0, 2*np.pi, 200)
  y = np.sin(x)
  z = np.cos(x)
  return x, y, z


def plot_line_graph(ax, data1, data2, title, xlabel, ylabel):
  axs[ax].plot(data1, data2, 'g-')
  axs[ax].set_title(f"{title}")
  axs[ax].set_xlabel(f"{xlabel}")
  axs[ax].set_ylabel(f"{ylabel}")




x_axis_data, y_axis_data, z_axis_data = generate_data()

fig, axs = plt.subplots(1, 2, figsize = (10, 2))

plot_line_graph(0, x_axis_data, y_axis_data, "Sine of X graph", "X", "Sin(x)")
plot_line_graph(1, x_axis_data, z_axis_data, "Cosine of X graph", "X", "Cos(x)")

# %%
def generate_data_2(range):
  x = np.random.randn(range)

  np.random.seed(40)
  y =  3 * x + 1

  np.random.seed(20)
  z = 8 * x

  return x, y, z



x_data, y_data, z_data = generate_data_2(10)
fig, axs = plt.subplots(1, 2, figsize = (10 ,4))
axs[0].scatter(y_data, x_data, s = 10, c = 'red', label = "Straight line 1")
axs[0].scatter(y_data,z_data,s = 10,c = 'blue',label = "Straight line 2")
axs[0].legend()
axs[0].set_xlabel("X data")
axs[0].set_ylabel("Y data")

# format strings
# fmt = [marker][line][color]
# for marker style - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
# marker style modified in line plot

axs[1].plot(y_data, x_data, '8-.m', label = "Straight line 1")
axs[1].plot(y_data,z_data,'4-.c',label = "Straight line 2")
axs[1].legend()
axs[1].set_xlabel("X data")
axs[1].set_ylabel("Y data")
"""
To modify location of legends in plots
==================   =============
    Location String      Location Code
    ==================   =============
    'best' (Axes only)   0
    'upper right'        1
    'upper left'         2
    'lower left'         3
    'lower right'        4
    'right'              5
    'center left'        6
    'center right'       7
    'lower center'       8
    'upper center'       9
    'center'             10
    ==================   =============
"""

plt.show()

# %%
"""
To change the styles of the graph
styles = ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']
"""

# with plt.xkcd():
plt.plot(y_data, x_data, '8-.m', label = "Straight line 1")
plt.plot(y_data,z_data,'4-.c',label = "Straight line 2")
plt.legend()
plt.style.use("default")
plt.xlabel("X data")
plt.ylabel("Y data")
plt.show()

# %%
student_data = pd.DataFrame({
    "Student ID" : ["STD" + str(i) for i in range(1000, 1011)],
    "Study Hours" : [i for i in range(2, 13)],
    "Marks" : [np.random.choice(np.arange(50 ,100)) for i in range(11)]

})
student_data
# Out:
#    Student ID  Study Hours  Marks
# 0     STD1000            2     85
# 1     STD1001            3     76
# 2     STD1002            4     65
# 3     STD1003            5     81
# 4     STD1004            6     78
# 5     STD1005            7     76
# 6     STD1006            8     59
# 7     STD1007            9     70
# 8     STD1008           10     61
# 9     STD1009           11     72
# 10    STD1010           12     57

# %%
plt.figure(figsize = (10, 5))
plt.bar(student_data['Student ID'], student_data['Marks'])
plt.xlabel("Student ID")
plt.ylabel("Marks")
plt.title("Student ID vs Marks")


for i in range(student_data['Student ID'].shape[0]):
  plt.text(student_data['Student ID'].iloc[i], student_data['Marks'].iloc[i]+ 2, str(student_data['Marks'].iloc[i]), ha = "center")
plt.tight_layout()
plt.ylim(0,max(student_data['Marks']+ 20))
plt.show()

# %%
# to view two different data on bar then we half the width two fit the two bars on the bar chart -
# width = 0.4
# plt.bar(x-width/2)
# plt.bar(x+width/2)
